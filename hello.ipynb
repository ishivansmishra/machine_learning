# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
df=pd.read_csv('heights_weights.csv')
df.head()
# Out:
#    Height_cm  weights_Kg
# 0        159          68
# 1        162          87
# 2        150          72
# 3        182          52
# 4        189          78

# %%
#scatter plot
plt.scatter(df['weights_Kg'], df['Height_cm'])
plt.xlabel('weights_kg')
plt.ylabel('Heights_cm')
# Out:
# Text(0, 0.5, 'Heights_cm')

# %%
#finding correlation between height and weight
df.corr()
# Out:
#             Height_cm  weights_Kg
# Height_cm    1.000000   -0.053309
# weights_Kg  -0.053309    1.000000

# %%
#seaborn Visuliztaion
import seaborn as sns
sns.pairplot(df)

# %%
#independent and dependent features
